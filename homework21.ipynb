# %% [markdown]
# **Задание 1**
#
# Ответьте на следующие вопросы:
#
# * Как критики относятся к спортивным играм?
#
# * Критикам нравятся больше игры на PC или на PS4?
#
# * Критикам больше нравятся стрелялки или стратегии?
#
# Для каждого вопроса:
#
# сформулируйте нулевую и альтернативную гипотезы;
# выберите пороговый уровень статистической значимости;
# опишите полученные результаты статистического теста.

# %%
import pandas as pd

# %%
df = pd.read_csv('vgsales.csv')
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
df = df.dropna()
df.describe()
# Out:
#        Year_of_Release     NA_Sales     EU_Sales     JP_Sales  Other_Sales  \
# count      6825.000000  6825.000000  6825.000000  6825.000000  6825.000000
# mean       2007.436777     0.394484     0.236089     0.064158     0.082677
# std           4.211248     0.967385     0.687330     0.287570     0.269871
# min        1985.000000     0.000000     0.000000     0.000000     0.000000
# 25%        2004.000000     0.060000     0.020000     0.000000     0.010000
# 50%        2007.000000     0.150000     0.060000     0.000000     0.020000
# 75%        2011.000000     0.390000     0.210000     0.010000     0.070000
# max        2016.000000    41.360000    28.960000     6.500000    10.570000
#
#        Global_Sales  Critic_Score  Critic_Count    User_Count
# count   6825.000000   6825.000000   6825.000000   6825.000000
# mean       0.777590     70.272088     28.931136    174.722344
# std        1.963443     13.868572     19.224165    587.428538
# ...

# %% [markdown]
# Среднее по всем играм - 70, так что ставим условие выше этого среднего
# H0: средняя удовлетворенность критиками спортивными играми <= 70
# H1: средняя удовлетворенность критиками спортивными играми более 70

# %%
df_sport = df[df['Genre'] == 'Sports']
df_sport
# Out:
#                               Name Platform  Year_of_Release   Genre  \
# 0                       Wii Sports      Wii           2006.0  Sports
# 3                Wii Sports Resort      Wii           2009.0  Sports
# 13                         Wii Fit      Wii           2007.0  Sports
# 15                    Wii Fit Plus      Wii           2009.0  Sports
# 77                         FIFA 16      PS4           2015.0  Sports
# ...                            ...      ...              ...     ...
# 16148       Don Bradman Cricket 14      PS3           2014.0  Sports
# 16233                Madden NFL 13      PS3           2012.0  Sports
# 16380    Tiger Woods PGA Tour 2005       PC           2004.0  Sports
# 16532    Pro Evolution Soccer 2010       PC           2009.0  Sports
# 16550  Wade Hixton's Counter Punch      GBA           2004.0  Sports
#
#                           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0                          Nintendo     41.36     28.96      3.77
# ...

# %%
df_sport.describe()
# Out:
#        Year_of_Release    NA_Sales    EU_Sales    JP_Sales  Other_Sales  \
# count       943.000000  943.000000  943.000000  943.000000   943.000000
# mean       2006.812301    0.485175    0.262386    0.036628     0.099735
# std           4.059768    1.572379    1.168906    0.242133     0.355126
# min        1998.000000    0.000000    0.000000    0.000000     0.000000
# 25%        2003.000000    0.100000    0.010000    0.000000     0.010000
# 50%        2006.000000    0.210000    0.060000    0.000000     0.030000
# 75%        2010.000000    0.480000    0.200000    0.000000     0.080000
# max        2016.000000   41.360000   28.960000    3.770000     8.450000
#
#        Global_Sales  Critic_Score  Critic_Count   User_Count
# count    943.000000    943.000000    943.000000   943.000000
# mean       0.884252     74.170732     23.345705    45.281018
# std        3.171441     13.187667     13.844270    93.309239
# min        0.010000     19.000000      4.000000     4.000000
# ...

# %%
from scipy import stats as st
alpha = 0.05
result = st.ttest_1samp(df_sport['Critic_Score'], 70, alternative='greater')

print(df_sport['Critic_Score'].mean())
print(result)

if result.pvalue < alpha: 
    print('Отвергаем нулевую гипотезу, среднее больше 70 (игры нравятся)')
else:
    print('Не отвергаем нулевую гипотезу')
# Out:
# 74.17073170731707
# Ttest_1sampResult(statistic=9.71180901421307, pvalue=1.2889782818622617e-21)
# Отвергаем нулевую гипотезу, среднее больше 70 (игры нравятся)

# %% [markdown]
# Получается, что в среднем критики ставят высокие оценки спортивным играм

# %% [markdown]
# H0: оценки критиков игры на PC не отличаются от оценок игр на PS4
# H1: оценки критиков игры на PC отличаются от оценок игр на PS4

# %%
df_pc = df[df['Platform'] == 'PC'][['Critic_Score']]
df_pc
# Out:
#        Critic_Score
# 85             86.0
# 138            93.0
# 192            88.0
# 218            93.0
# 284            96.0
# ...             ...
# 16624          80.0
# 16644          51.0
# 16696          80.0
# 16700          61.0
# 16706          60.0
#
# [651 rows x 1 columns]

# %%
df_ps = df[df['Platform'] == 'PS4'][['Critic_Score']]
df_ps
# Out:
#        Critic_Score
# 42             97.0
# 77             82.0
# 92             83.0
# 94             85.0
# 105            87.0
# ...             ...
# 16137          66.0
# 16490          42.0
# 16503          70.0
# 16530          61.0
# 16534          51.0
#
# [239 rows x 1 columns]

# %%
st.ttest_ind(df_pc, df_ps)
# Out:
# Ttest_indResult(statistic=array([4.17122694]), pvalue=array([3.32704805e-05]))

# %% [markdown]
# pvalue меньше 0.05 - различия не существенны

# %%
df[df['Genre'] == 'Sports']
